# %%
print("hello")
# Out:
# hello

# %%
# Import necessary libraries
from pybaseball import batting_stats
import pandas as pd

# Fetch batting stats data for the years 2015 to 2022
data = batting_stats(2015, 2022)

# Look at the first few rows of the DataFrame
print(data.head())
# Out:
#      IDfg  Season          Name Team  Age    G   AB   PA    H  1B  ...  maxEV
# 2   15640    2022   Aaron Judge  NYY   30  157  570  696  177  87  ...  118.4  \
# 4   13611    2018  Mookie Betts  BOS   25  136  520  614  180  96  ...  110.6
# 5   10155    2018    Mike Trout  LAA   26  140  471  608  147  80  ...  118.0
# 1   11579    2015  Bryce Harper  WSN   22  153  521  654  172  91  ...  116.0
# 27  10155    2015    Mike Trout  LAA   23  159  575  682  172  93  ...  117.7
#
#     HardHit  HardHit%  Events  CStr%   CSW%  xBA  xSLG  xwOBA  L-WAR
# 2       246     0.609     404  0.169  0.287  NaN   NaN    NaN   11.2
# 4       217     0.500     434  0.220  0.270  NaN   NaN    NaN   10.4
# 5       162     0.460     352  0.201  0.261  NaN   NaN    NaN    9.6
# 1       188     0.477     394  0.118  0.226  NaN   NaN    NaN    9.3
# 27      205     0.486     422  0.207  0.282  NaN   NaN    NaN    9.3
#
# [5 rows x 320 columns]
# IDfg         0
# Season       0
# Name         0
# Team         0
# Age          0
#           ...
# CSW%         0
# xBA       1110
# xSLG      1110
# xwOBA     1110
# L-WAR        0
# Length: 320, dtype: int64
#                IDfg       Season          Age            G           AB
# count   1110.000000  1110.000000  1110.000000  1110.000000  1110.000000  \
# mean   10694.104505  2018.428829    28.397297   134.400901   495.466667
# std     5236.994431     2.279773     3.690921    32.009306   124.440759
# min      393.000000  2015.000000    20.000000    44.000000   154.000000
# 25%     6012.000000  2016.000000    26.000000   134.000000   476.250000
# 50%    11200.000000  2018.000000    28.000000   145.000000   526.000000
# 75%    14344.000000  2020.000000    31.000000   153.750000   573.000000
# max    27506.000000  2022.000000    41.000000   162.000000   681.000000
#
#                 PA            H           1B           2B           3B  ...
# count  1110.000000  1110.000000  1110.000000  1110.000000  1110.000000  ...  \
# mean    555.682883   133.098198    83.755856    26.629730     2.483784  ...
# std     138.814283    38.128967    27.610632     9.461841     2.322744  ...
# min     186.000000    32.000000    13.000000     3.000000     0.000000  ...
# 25%     533.000000   120.000000    70.000000    22.000000     1.000000  ...
# 50%     589.000000   139.000000    86.000000    27.000000     2.000000  ...
# 75%     647.000000   158.000000   102.000000    33.000000     4.000000  ...
# max     747.000000   216.000000   170.000000    58.000000    14.000000  ...
#
#              maxEV      HardHit     HardHit%       Events        CStr%
# count  1110.000000  1110.000000  1110.000000  1110.000000  1110.000000  \
# mean    111.247928   148.559459     0.383780   391.452252     0.161683
# std       3.102663    47.351758     0.076791   107.610002     0.031239
# min     101.900000    26.000000     0.085000    96.000000     0.076000
# 25%     109.200000   125.000000     0.339000   360.000000     0.141000
# 50%     111.100000   154.000000     0.389000   414.000000     0.161000
# 75%     113.200000   180.000000     0.431750   461.000000     0.182000
# max     122.200000   274.000000     0.622000   599.000000     0.284000
#
#               CSW%  xBA  xSLG  xwOBA        L-WAR
# count  1110.000000  0.0   0.0    0.0  1110.000000
# mean      0.262962  NaN   NaN    NaN     2.692342
# std       0.025917  NaN   NaN    NaN     1.985149
# min       0.175000  NaN   NaN    NaN    -3.100000
# 25%       0.246000  NaN   NaN    NaN     1.300000
# 50%       0.263000  NaN   NaN    NaN     2.500000
# 75%       0.281000  NaN   NaN    NaN     3.900000
# max       0.355000  NaN   NaN    NaN    11.200000
#
# [8 rows x 316 columns]

# %%
# Check for missing values
print(data.isnull().sum())
# Out:
# IDfg         0
# Season       0
# Name         0
# Team         0
# Age          0
#           ...
# CSW%         0
# xBA       1110
# xSLG      1110
# xwOBA     1110
# L-WAR        0
# Length: 320, dtype: int64

# %%
# Summary statistics
print(data.describe())
# Out:
#                IDfg       Season          Age            G           AB
# count   1110.000000  1110.000000  1110.000000  1110.000000  1110.000000  \
# mean   10694.104505  2018.428829    28.397297   134.400901   495.466667
# std     5236.994431     2.279773     3.690921    32.009306   124.440759
# min      393.000000  2015.000000    20.000000    44.000000   154.000000
# 25%     6012.000000  2016.000000    26.000000   134.000000   476.250000
# 50%    11200.000000  2018.000000    28.000000   145.000000   526.000000
# 75%    14344.000000  2020.000000    31.000000   153.750000   573.000000
# max    27506.000000  2022.000000    41.000000   162.000000   681.000000
#
#                 PA            H           1B           2B           3B  ...
# count  1110.000000  1110.000000  1110.000000  1110.000000  1110.000000  ...  \
# mean    555.682883   133.098198    83.755856    26.629730     2.483784  ...
# std     138.814283    38.128967    27.610632     9.461841     2.322744  ...
# min     186.000000    32.000000    13.000000     3.000000     0.000000  ...
# 25%     533.000000   120.000000    70.000000    22.000000     1.000000  ...
# 50%     589.000000   139.000000    86.000000    27.000000     2.000000  ...
# 75%     647.000000   158.000000   102.000000    33.000000     4.000000  ...
# max     747.000000   216.000000   170.000000    58.000000    14.000000  ...
#
#              maxEV      HardHit     HardHit%       Events        CStr%
# count  1110.000000  1110.000000  1110.000000  1110.000000  1110.000000  \
# mean    111.247928   148.559459     0.383780   391.452252     0.161683
# std       3.102663    47.351758     0.076791   107.610002     0.031239
# min     101.900000    26.000000     0.085000    96.000000     0.076000
# 25%     109.200000   125.000000     0.339000   360.000000     0.141000
# 50%     111.100000   154.000000     0.389000   414.000000     0.161000
# 75%     113.200000   180.000000     0.431750   461.000000     0.182000
# max     122.200000   274.000000     0.622000   599.000000     0.284000
#
#               CSW%  xBA  xSLG  xwOBA        L-WAR
# count  1110.000000  0.0   0.0    0.0  1110.000000
# mean      0.262962  NaN   NaN    NaN     2.692342
# std       0.025917  NaN   NaN    NaN     1.985149
# min       0.175000  NaN   NaN    NaN    -3.100000
# 25%       0.246000  NaN   NaN    NaN     1.300000
# 50%       0.263000  NaN   NaN    NaN     2.500000
# 75%       0.281000  NaN   NaN    NaN     3.900000
# max       0.355000  NaN   NaN    NaN    11.200000
#
# [8 rows x 316 columns]
